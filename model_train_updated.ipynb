# %%
import pandas as pd
import numpy as np
import json

# %%
# load the collected datapoints json file
df_yoga = pd.read_json('model/datapoints-ml5/yoga.json')

# %%
df_yoga_val = pd.read_json('model/datapoints-ml5/soumya-training.json')

# %%
# with pd.option_context('display.max_rows',None,'display.max_columns',None):
print(df_yoga)
# Out:
#                                                    data
# 0     {'xs': {'0': 265.4053324963826, '1': 263.00019...
# 1     {'xs': {'0': 265.4053324963826, '1': 263.00019...
# 2     {'xs': {'0': 273.27526685552493, '1': 263.4545...
# 3     {'xs': {'0': 273.27526685552493, '1': 263.4545...
# 4     {'xs': {'0': 273.27526685552493, '1': 263.4545...
# ...                                                 ...
# 3664  {'xs': {'0': 354.3905301063502, '1': 334.18770...
# 3665  {'xs': {'0': 353.53565536145953, '1': 330.8824...
# 3666  {'xs': {'0': 351.02515053476293, '1': 333.6118...
# 3667  {'xs': {'0': 346.42412131427824, '1': 333.4233...
# 3668  {'xs': {'0': 352.81592789454635, '1': 336.4396...
#
# [3669 rows x 1 columns]

# %%
# to get the individual angles of a pose
# for i in range(14):
#     print(df_yoga.at[0,'data'].get('xs').get(str(i)))

# %%
# to get the label
# df_yoga.at[0,'data'].get('ys').get('0')

# %%
columns = ['a0', 'a1', 'a2', 'a3', 'a4', 'a5', 'a6', 'a7', 'a8', 'a9', 'a10', 'a11', 'a12', 'a13', 'pose']
df_filtered = pd.DataFrame(columns=columns)

# %%
df_filtered_test = pd.DataFrame(columns=columns)

# %%
# len(df_yoga.at[0,'data'].get('xs'))

# %%
# putting everything together for the training data
# loop through the pandas yoga rows
for i in range(len(df_yoga)):
    temp_arr = []
    # get the points first
    for j in range(14):
        temp_arr.append(df_yoga.at[i,'data'].get('xs').get(str(j)))
    # get the label
    temp_arr.append(df_yoga.at[i,'data'].get('ys').get('0'))
    df_filtered.loc[i] = temp_arr
df_filtered
# Out:
#               a0          a1          a2          a3         a4          a5  \
# 0     265.405332  263.000193  279.886341  257.806562  68.595548  114.238489
# 1     265.405332  263.000193  279.886341  257.806562  68.595548  114.238489
# 2     273.275267  263.454578  275.091656  257.369954  69.419626  114.136569
# 3     273.275267  263.454578  275.091656  257.369954  69.419626  114.136569
# 4     273.275267  263.454578  275.091656  257.369954  69.419626  114.136569
# ...          ...         ...         ...         ...        ...         ...
# 3664  354.390530  334.187700  270.013641  229.634137  25.692325   73.407152
# 3665  353.535655  330.882497  271.113020  213.900575  24.639241  179.259830
# 3666  351.025151  333.611834  267.406741  231.325003  25.488751   35.818644
# 3667  346.424121  333.423326  269.028146  214.706653  18.957976  177.416679
# 3668  352.815928  336.439676  270.895469  229.265524  23.542116  357.684727
#
# ...

# %%
# find the average of each angle for mountain
df_mountain = df_filtered.loc[df_filtered['pose'] == 'Mountain']
a0 = 0
a1 = 0
a2 = 0
a3 = 0
a4 = 0
a5 = 0
a6 = 0
a7 = 0
a8 = 0
a9 = 0
a10 = 0
a11 = 0
a12 = 0
a13 = 0

# loop through each angle
# a0
for i in df_mountain['a0']:
    a0 += i
a0_ave = a0 / len(df_mountain)

print(f'average of a0: {a0_ave}')

# a1
for i in df_mountain['a1']:
    a1 += i
a1_ave = a1 / len(df_mountain)

print(f'average of a1: {a1_ave}')

# a2
for i in df_mountain['a2']:
    a2 += i
a2_ave = a2 / len(df_mountain)

print(f'average of a2: {a2_ave}')

# a3
for i in df_mountain['a3']:
    a3 += i
a3_ave = a3 / len(df_mountain)

print(f'average of a3: {a3_ave}')

# a4
for i in df_mountain['a4']:
    a4 += i
a4_ave = a4 / len(df_mountain)

print(f'average of a4: {a4_ave}')

# a5
for i in df_mountain['a5']:
    a5 += i
a5_ave = a5 / len(df_mountain)

print(f'average of a5: {a5_ave}')

# a0
for i in df_mountain['a6']:
    a6 += i
a6_ave = a6 / len(df_mountain)

print(f'average of a6: {a6_ave}')

# a7
for i in df_mountain['a7']:
    a7 += i
a7_ave = a7 / len(df_mountain)

print(f'average of a7: {a7_ave}')

# a8
for i in df_mountain['a8']:
    a8 += i
a8_ave = a8 / len(df_mountain)

print(f'average of a8: {a8_ave}')

# a9
for i in df_mountain['a9']:
    a9 += i
a9_ave = a9 / len(df_mountain)

print(f'average of a9: {a9_ave}')

# a10
for i in df_mountain['a10']:
    a10 += i
a10_ave = a10 / len(df_mountain)

print(f'average of a10: {a10_ave}')

# a11
for i in df_mountain['a11']:
    a11 += i
a11_ave = a11 / len(df_mountain)

print(f'average of a11: {a11_ave}')

# a12
for i in df_mountain['a12']:
    a12 += i
a12_ave = a12 / len(df_mountain)

print(f'average of a12: {a12_ave}')

# a13
for i in df_mountain['a13']:
    a13 += i
a13_ave = a13 / len(df_mountain)

print(f'average of a13: {a13_ave}')
# Out:
# average of a0: 267.92894477076163
# average of a1: 267.8780003541165
# average of a2: 277.3238868249885
# average of a3: 259.9553736248052
# average of a4: 67.79409019955855
# average of a5: 113.05005891225755
# average of a6: 271.2225081996758
# average of a7: 274.2705337344385
# average of a8: 71.86728094123826
# average of a9: 108.55981758065309
# average of a10: 71.23896710298241
# average of a11: 110.48009368058477
# average of a12: 68.2499478038741
# average of a13: 114.95071948883633

# %%
# find the average of each angle for tree
df_tree = df_filtered.loc[df_filtered['pose'] == 'Tree']
a0 = 0
a1 = 0
a2 = 0
a3 = 0
a4 = 0
a5 = 0
a6 = 0
a7 = 0
a8 = 0
a9 = 0
a10 = 0
a11 = 0
a12 = 0
a13 = 0

# loop through each angle
# a0
for i in df_tree['a0']:
    a0 += i
a0_ave = a0 / len(df_tree)

print(f'average of a0: {a0_ave}')

# a1
for i in df_tree['a1']:
    a1 += i
a1_ave = a1 / len(df_tree)

print(f'average of a1: {a1_ave}')

# a2
for i in df_tree['a2']:
    a2 += i
a2_ave = a2 / len(df_tree)

print(f'average of a2: {a2_ave}')

# a3
for i in df_tree['a3']:
    a3 += i
a3_ave = a3 / len(df_tree)

print(f'average of a3: {a3_ave}')

# a4
for i in df_tree['a4']:
    a4 += i
a4_ave = a4 / len(df_tree)

print(f'average of a4: {a4_ave}')

# a5
for i in df_tree['a5']:
    a5 += i
a5_ave = a5 / len(df_tree)

print(f'average of a5: {a5_ave}')

# a0
for i in df_tree['a6']:
    a6 += i
a6_ave = a6 / len(df_tree)

print(f'average of a6: {a6_ave}')

# a7
for i in df_tree['a7']:
    a7 += i
a7_ave = a7 / len(df_tree)

print(f'average of a7: {a7_ave}')

# a8
for i in df_tree['a8']:
    a8 += i
a8_ave = a8 / len(df_tree)

print(f'average of a8: {a8_ave}')

# a9
for i in df_tree['a9']:
    a9 += i
a9_ave = a9 / len(df_tree)

print(f'average of a9: {a9_ave}')

# a10
for i in df_tree['a10']:
    a10 += i
a10_ave = a10 / len(df_tree)

print(f'average of a10: {a10_ave}')

# a11
for i in df_tree['a11']:
    a11 += i
a11_ave = a11 / len(df_tree)

print(f'average of a11: {a11_ave}')

# a12
for i in df_tree['a12']:
    a12 += i
a12_ave = a12 / len(df_tree)

print(f'average of a12: {a12_ave}')

# a13
for i in df_tree['a13']:
    a13 += i
a13_ave = a13 / len(df_tree)

print(f'average of a13: {a13_ave}')

# %%
# find the average of each angle for goddess
df_goddess = df_filtered.loc[df_filtered['pose'] == 'Goddess']
a0 = 0
a1 = 0
a2 = 0
a3 = 0
a4 = 0
a5 = 0
a6 = 0
a7 = 0
a8 = 0
a9 = 0
a10 = 0
a11 = 0
a12 = 0
a13 = 0

# loop through each angle
# a0
for i in df_goddess['a0']:
    a0 += i
a0_ave = a0 / len(df_goddess)

print(f'average of a0: {a0_ave}')

# a1
for i in df_goddess['a1']:
    a1 += i
a1_ave = a1 / len(df_goddess)

print(f'average of a1: {a1_ave}')

# a2
for i in df_goddess['a2']:
    a2 += i
a2_ave = a2 / len(df_goddess)

print(f'average of a2: {a2_ave}')

# a3
for i in df_goddess['a3']:
    a3 += i
a3_ave = a3 / len(df_goddess)

print(f'average of a3: {a3_ave}')

# a4
for i in df_goddess['a4']:
    a4 += i
a4_ave = a4 / len(df_goddess)

print(f'average of a4: {a4_ave}')

# a5
for i in df_goddess['a5']:
    a5 += i
a5_ave = a5 / len(df_goddess)

print(f'average of a5: {a5_ave}')

# a0
for i in df_goddess['a6']:
    a6 += i
a6_ave = a6 / len(df_goddess)

print(f'average of a6: {a6_ave}')

# a7
for i in df_goddess['a7']:
    a7 += i
a7_ave = a7 / len(df_goddess)

print(f'average of a7: {a7_ave}')

# a8
for i in df_goddess['a8']:
    a8 += i
a8_ave = a8 / len(df_goddess)

print(f'average of a8: {a8_ave}')

# a9
for i in df_goddess['a9']:
    a9 += i
a9_ave = a9 / len(df_goddess)

print(f'average of a9: {a9_ave}')

# a10
for i in df_goddess['a10']:
    a10 += i
a10_ave = a10 / len(df_goddess)

print(f'average of a10: {a10_ave}')

# a11
for i in df_goddess['a11']:
    a11 += i
a11_ave = a11 / len(df_goddess)

print(f'average of a11: {a11_ave}')

# a12
for i in df_goddess['a12']:
    a12 += i
a12_ave = a12 / len(df_goddess)

print(f'average of a12: {a12_ave}')

# a13
for i in df_goddess['a13']:
    a13 += i
a13_ave = a13 / len(df_goddess)

print(f'average of a13: {a13_ave}')
# Out:
# average of a0: 225.88885592550653
# average of a1: 289.77050330017727
# average of a2: 307.4745261477588
# average of a3: 237.38432674502604
# average of a4: 76.15758200509772
# average of a5: 128.91455784145754
# average of a6: 153.43257420061298
# average of a7: 146.67738812015926
# average of a8: 225.0465274947821
# average of a9: 128.01321786535468
# average of a10: 174.48409168395932
# average of a11: 122.92636830868251
# average of a12: 227.64397007714732
# average of a13: 135.78139548534

# %%
# find the average of each angle for goddess
df_warrior2 = df_filtered.loc[df_filtered['pose'] == 'Warrior 2']
a0 = 0
a1 = 0
a2 = 0
a3 = 0
a4 = 0
a5 = 0
a6 = 0
a7 = 0
a8 = 0
a9 = 0
a10 = 0
a11 = 0
a12 = 0
a13 = 0

# loop through each angle
# a0
for i in df_warrior2['a0']:
    a0 += i
a0_ave = a0 / len(df_warrior2)

print(f'average of a0: {a0_ave}')

# a1
for i in df_warrior2['a1']:
    a1 += i
a1_ave = a1 / len(df_warrior2)

print(f'average of a1: {a1_ave}')

# a2
for i in df_warrior2['a2']:
    a2 += i
a2_ave = a2 / len(df_warrior2)

print(f'average of a2: {a2_ave}')

# a3
for i in df_warrior2['a3']:
    a3 += i
a3_ave = a3 / len(df_warrior2)

print(f'average of a3: {a3_ave}')

# a4
for i in df_warrior2['a4']:
    a4 += i
a4_ave = a4 / len(df_warrior2)

print(f'average of a4: {a4_ave}')

# a5
for i in df_warrior2['a5']:
    a5 += i
a5_ave = a5 / len(df_warrior2)

print(f'average of a5: {a5_ave}')

# a0
for i in df_warrior2['a6']:
    a6 += i
a6_ave = a6 / len(df_warrior2)

print(f'average of a6: {a6_ave}')

# a7
for i in df_warrior2['a7']:
    a7 += i
a7_ave = a7 / len(df_warrior2)

print(f'average of a7: {a7_ave}')

# a8
for i in df_warrior2['a8']:
    a8 += i
a8_ave = a8 / len(df_warrior2)

print(f'average of a8: {a8_ave}')

# a9
for i in df_warrior2['a9']:
    a9 += i
a9_ave = a9 / len(df_warrior2)

print(f'average of a9: {a9_ave}')

# a10
for i in df_warrior2['a10']:
    a10 += i
a10_ave = a10 / len(df_warrior2)

print(f'average of a10: {a10_ave}')

# a11
for i in df_warrior2['a11']:
    a11 += i
a11_ave = a11 / len(df_warrior2)

print(f'average of a11: {a11_ave}')

# a12
for i in df_warrior2['a12']:
    a12 += i
a12_ave = a12 / len(df_warrior2)

print(f'average of a12: {a12_ave}')

# a13
for i in df_warrior2['a13']:
    a13 += i
a13_ave = a13 / len(df_warrior2)

print(f'average of a13: {a13_ave}')
# Out:
# average of a0: 254.2574417170418
# average of a1: 297.9138227780071
# average of a2: 296.2176716334106
# average of a3: 242.57483782424563
# average of a4: 76.04822758587075
# average of a5: 130.35657220772438
# average of a6: 257.86604953604416
# average of a7: 232.2876329623176
# average of a8: 40.0474076923995
# average of a9: 134.587835937805
# average of a10: 39.81237001227132
# average of a11: 132.03137892303735
# average of a12: 82.78598241066567
# average of a13: 140.9961034041264

# %%
# putting everything together for the testing data
# loop through the pandas yoga rows
for i in range(len(df_yoga_val)):
    temp_arr = []
    # get the points first
    for j in range(14):
        temp_arr.append(df_yoga_val.at[i,'data'].get('xs').get(str(j)))
    # get the label
    temp_arr.append(df_yoga_val.at[i,'data'].get('ys').get('0'))
    df_filtered_test.loc[i] = temp_arr
df_filtered_test
# Out:
#               a0          a1          a2          a3         a4          a5  \
# 0     262.829400  272.297768  276.926342  257.941081  67.641550  122.928871
# 1     266.112725  267.479192  280.590459  258.961041  68.864943  121.340929
# 2     265.166085  268.103886  276.459497  258.426849  67.062957  121.761550
# 3     286.304905  270.303705  262.840032  258.077288  74.220968  121.312036
# 4     274.273069  274.021116  263.054334  258.831674  74.003741  121.103647
# ...          ...         ...         ...         ...        ...         ...
# 1189  243.759122  294.891549  306.644064  239.816198  73.806410  131.688681
# 1190  244.907487  285.394757  303.848545  234.404463  74.194208  132.855612
# 1191  246.801035  279.330472  307.787391  241.595770  76.203089  132.871096
# 1192  252.458518  274.431917  303.442322  245.160485  76.501370  129.967660
# 1193  254.381720  269.202862  301.048837  250.580318  82.212792  129.007562
#
# ...

# %%
# need to have numeric labels for tensorflow model
labels_num = []
pose_col = df_filtered['pose']
for i in range(len(pose_col)):
    if (pose_col[i]) == 'Mountain':
        labels_num.append(0)
    elif (pose_col[i]) == 'Tree':
        labels_num.append(1)
    elif (pose_col[i]) == 'Goddess':
        labels_num.append(2)
    elif (pose_col[i]) == 'Warrior 2':
        labels_num.append(3)
        
labels_num = np.array(labels_num)
# labels_num

# %%
# for testing data
labels_num_test = []
pose_col = df_filtered_test['pose']
for i in range(len(pose_col)):
    if (pose_col[i]) == 'Mountain':
        labels_num_test.append(0)
    elif (pose_col[i]) == 'Tree':
        labels_num_test.append(1)
    elif (pose_col[i]) == 'Goddess':
        labels_num_test.append(2)
    elif (pose_col[i]) == 'Warrior 2':
        labels_num_test.append(3)
        
labels_num_test = np.array(labels_num_test)
# labels_num_test

# %%
# dropping last col with pose names
df_filtered.drop(df_filtered.columns[-1], axis=1, inplace=True)

# %%
df_filtered_test.drop(df_filtered_test.columns[-1], axis=1, inplace=True)

# %%
# from sklearn.model_selection import train_test_split

# %%
# features_train, features_test, labels_train, labels_test = train_test_split(df_filtered, labels_num, test_size=0.30, random_state=42)

# %%
# scale the data
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
# scale the training data
scaler.fit(df_filtered)
# Out:
# MinMaxScaler()

# %%
# scale the testing data
scaler.fit(df_filtered_test)
# Out:
# MinMaxScaler()

# %%
# norm the training data
features_train = scaler.transform(df_filtered)

# %%
# norm the validation data
features_test = scaler.transform(df_filtered_test)
# features_test = scaler.transform(features_test)

# %%
# features_train

# %%
# features_test

# %%
import tensorflow as tf

# %%
from tensorflow.keras.layers import Input, Dense, Activation, Dropout
from tensorflow.keras.models import Model

# %%
input_layer = Input(shape=(df_filtered.shape[1],))

# %%
dense_layer_1 = Dense(15, activation='relu')(input_layer)

# %%
dense_layer_2 = Dense(10, activation='relu')(dense_layer_1)

# %%
output = Dense(4, activation='softmax')(dense_layer_2)

# %%
model = Model(inputs=input_layer, outputs=output)

# %%
model.compile(loss='sparse_categorical_crossentropy',optimizer='adam',metrics=['acc'])

# %%
history = model.fit(features_train,labels_num,batch_size=8,epochs=100,verbose=1)
# Out:
# Train on 2782 samples
# Epoch 1/100
# 2782/2782 [==============================] - 0s 100us/sample - loss: 1.2606 - acc: 0.5712
# Epoch 2/100
# 2782/2782 [==============================] - 0s 87us/sample - loss: 0.7485 - acc: 0.7189
# Epoch 3/100
# 2782/2782 [==============================] - 0s 82us/sample - loss: 0.4194 - acc: 0.8659
# Epoch 4/100
# 2782/2782 [==============================] - 0s 81us/sample - loss: 0.3195 - acc: 0.8961
# Epoch 5/100
# 2782/2782 [==============================] - 0s 87us/sample - loss: 0.2763 - acc: 0.9058
# Epoch 6/100
# 2782/2782 [==============================] - 0s 97us/sample - loss: 0.2506 - acc: 0.9148
# Epoch 7/100
# 2782/2782 [==============================] - 0s 88us/sample - loss: 0.2322 - acc: 0.9198
# Epoch 8/100
# 2782/2782 [==============================] - 0s 76us/sample - loss: 0.2152 - acc: 0.9263
# Epoch 9/100
# 2782/2782 [==============================] - 0s 74us/sample - loss: 0.2031 - acc: 0.9310
# Epoch 10/100
# ...

# %%
# get the validation data
score = model.evaluate(features_test, labels_num_test, verbose=1)
# Out:
# 1194/1194 [==============================] - 0s 31us/sample - loss: 0.4699 - acc: 0.8300

# %%
print("loss score: ",  score[0])
# Out:
# loss score:  0.46993591165453996

# %%
print("test accuracy: ", score[1])
# Out:
# test accuracy:  0.82998323
